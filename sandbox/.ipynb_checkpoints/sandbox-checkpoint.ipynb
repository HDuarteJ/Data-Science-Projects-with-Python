# %% [markdown]
# 1. Teste
# 2. Teaste
# 3. Teaste

# %% [markdown]
# - Teste
# - Teste
# - Teste
# - Teste
# - Teste
# - Teste

# %% [markdown]
# Teste | Teste | Teste | Teste | Teste | Teste |
# ------|-------|-------|-------|-------|-------|
#    1  |   2   |   3   |   4   |   5   |    6  |
#    1  |   2   |   3   |   4   |   5   |    6  |
#    1  |   2   |   3   |   4   |   5   |    6  |
#    1  |   2   |   3   |   4   |   5   |    6  |

# %%
print("Carregando", end="")
for _ in range(5):
    time.sleep(0.5)
    # Sem o flush=True, você não veria os pontos aparecendo um a um
    print(".", end="", flush='F) 
print("\nConcluído!")
# Out:
# Carregando.....
# Concluído!
