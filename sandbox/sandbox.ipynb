# %% [markdown]
# 1. Teste
# 2. Teaste
# 3. Teaste

# %% [markdown]
# - Teste
# - Teste
# - Teste
# - Teste
# - Teste
# - Teste

# %% [markdown]
# Teste | Teste | Teste | Teste | Teste | Teste |
# ------|-------|-------|-------|-------|-------|
#    1  |   2   |   3   |   4   |   5   |    6  |
#    1  |   2   |   3   |   4   |   5   |    6  |
#    1  |   2   |   3   |   4   |   5   |    6  |
#    1  |   2   |   3   |   4   |   5   |    6  |

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Chapter_1_cleaned_data.csv")

# %%
df.shape
# Out:
# (26664, 31)
